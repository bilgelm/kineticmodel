# %%
import os
import numpy as np
import nibabel as nib
from kineticmodel import SRTM_Zhou2003, SRTM_Lammertsma1996

data_path = 'data/'
inputTac_filename = os.path.join(data_path, 'input.mni305.2mm.sm6.nii.gz')
cerebMask_filename = os.path.join(data_path, 'cereb.mni305.2mm.nii.gz')
tim_filename = os.path.join(data_path, 'info_tim.csv')

inputTac = nib.load(inputTac_filename)
cerebMask = nib.load(cerebMask_filename)

results_img = SRTM_Zhou2003.volume_wrapper(timeSeriesImgFile=inputTac_filename,frameTimingCsvFile=tim_filename,refRegionMaskFile=cerebMask_filename,time_unit='s',startActivity='flat',fwhm=(2*np.sqrt(2*np.log(2))) * 5)
# Out:
# /Users/bilgelm/Research/kineticmodel/kineticmodel/kineticmodel.py:295: RuntimeWarning: invalid value encountered in true_divide
#   h[:,0] = gaussian_filter(m * noiseVar_eqR1_wlr / np.square(R1_wlr - smooth_R1_wlr),
# /Users/bilgelm/Research/kineticmodel/kineticmodel/kineticmodel.py:297: RuntimeWarning: invalid value encountered in true_divide
#   h[:,1] = gaussian_filter(m * noiseVar_eqR1_wlr / np.square(k2_wlr - smooth_k2_wlr),
# /Users/bilgelm/Research/kineticmodel/kineticmodel/kineticmodel.py:299: RuntimeWarning: invalid value encountered in true_divide
#   h[:,2] = gaussian_filter(m * noiseVar_eqR1_wlr / np.square(k2a_wlr - smooth_k2a_wlr),

# %%
results_img.keys()
BP_img = results_img['BP']

import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(BP_img[:,:,20])

# %%
plt.imshow(BP_img[:,:,5])
